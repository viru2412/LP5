# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout
# Out:
# WARNING:tensorflow:From C:\ProgramData\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
df= pd.read_csv('Google_Stock_Price_Train.csv')

# %%
df.head()
# Out:
#          Date    Open    High     Low   Close      Volume
# 0  01/03/2012  325.25  332.83  324.97  663.59   7,380,500
# 1  01/04/2012  331.27  333.87  329.08  666.45   5,749,400
# 2  01/05/2012  329.83  330.75  326.89  657.21   6,590,300
# 3  01/06/2012  328.34  328.77  323.68  648.24   5,405,900
# 4  01/09/2012  322.04  322.29  309.46  620.76  11,688,800

# %%
training_set = df.iloc[:, 1: 2].values

# %%
training_set.shape
# Out:
# (1509, 1)

# %%
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)

# %%
X_train = []
y_train = []
for i in range(60, len(training_set_scaled)):
    X_train.append(training_set_scaled[i-60: i, 0])
    y_train.append(training_set_scaled[i, 0])

X_train, y_train = np.array(X_train), np.array(y_train)

# %%
X_train.shape
# Out:
# (1449, 60)

# %%
y_train.shape
# Out:
# (1449,)

# %%
X_train = np.reshape(X_train, newshape = 
                     (X_train.shape[0], X_train.shape[1], 1))

# %%
X_train.shape
# Out:
# (1449, 60, 1)

# %%
plt.figure(figsize=(18, 8))
plt.plot(df['Open'])
plt.title("Google Stock Open Prices")
plt.xlabel("Time (oldest -> latest)")
plt.ylabel("Stock Open Price")
plt.show()

# %%
plt.figure(figsize=(18, 8))
plt.plot(df['Low'])
plt.title("Google Stock Low Prices")
plt.xlabel("Time (oldest -> latest)")
plt.ylabel("Stock Lowest Price")
plt.show()

# %%
regressor = Sequential()
#add 1st lstm layer
regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
regressor.add(Dropout(rate = 0.2))

##add 2nd lstm layer: 50 neurons
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(rate = 0.2))

##add 3rd lstm layer
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(rate = 0.2))

##add 4th lstm layer
regressor.add(LSTM(units = 50, return_sequences = False))
regressor.add(Dropout(rate = 0.2))

##add output layer
regressor.add(Dense(units = 1))
# Out:
# WARNING:tensorflow:From C:\ProgramData\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')
# Out:
# WARNING:tensorflow:From C:\ProgramData\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
regressor.fit(x = X_train, y = y_train, batch_size = 32, epochs = 100)
# Out:
# Epoch 1/100
# WARNING:tensorflow:From C:\ProgramData\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 46/46 [==============================] - 25s 150ms/step - loss: 0.0316
# Epoch 2/100
# 46/46 [==============================] - 7s 144ms/step - loss: 0.0042
# Epoch 3/100
# 46/46 [==============================] - 6s 130ms/step - loss: 0.0037
# Epoch 4/100
# 46/46 [==============================] - 6s 137ms/step - loss: 0.0033
# Epoch 5/100
# 46/46 [==============================] - 7s 144ms/step - loss: 0.0031
# Epoch 6/100
# 46/46 [==============================] - 6s 141ms/step - loss: 0.0034
# Epoch 7/100
# 46/46 [==============================] - 6s 124ms/step - loss: 0.0031
# Epoch 8/100
# 46/46 [==============================] - 6s 131ms/step - loss: 0.0028
# Epoch 9/100
# 46/46 [==============================] - 6s 135ms/step - loss: 0.0030
# Epoch 10/100
# 46/46 [==============================] - 6s 141ms/step - loss: 0.0026
# Epoch 11/100
# 46/46 [==============================] - 7s 147ms/step - loss: 0.0028
# Epoch 12/100
# 46/46 [==============================] - 6s 141ms/step - loss: 0.0034
# Epoch 13/100
# 46/46 [==============================] - 7s 146ms/step - loss: 0.0026
# Epoch 14/100
# 46/46 [==============================] - 6s 140ms/step - loss: 0.0027
# Epoch 15/100
# 46/46 [==============================] - 7s 145ms/step - loss: 0.0027
# Epoch 16/100
# 46/46 [==============================] - 7s 142ms/step - loss: 0.0023
# Epoch 17/100
# 46/46 [==============================] - 7s 145ms/step - loss: 0.0026
# Epoch 18/100
# 46/46 [==============================] - 7s 144ms/step - loss: 0.0023
# Epoch 19/100
# 46/46 [==============================] - 5s 108ms/step - loss: 0.0019
# Epoch 20/100
# 46/46 [==============================] - 6s 135ms/step - loss: 0.0024
# Epoch 21/100
# 46/46 [==============================] - 5s 103ms/step - loss: 0.0022
# Epoch 22/100
# 46/46 [==============================] - 6s 139ms/step - loss: 0.0028
# Epoch 23/100
# 46/46 [==============================] - 7s 152ms/step - loss: 0.0020
# Epoch 24/100
# 46/46 [==============================] - 7s 142ms/step - loss: 0.
# 46/46 [==============================] - 6s 140ms/step - loss: 0.0011
# Epoch 80/100
# 46/46 [==============================] - 7s 155ms/step - loss: 0.0012
# Epoch 81/100
# 46/46 [==============================] - 7s 143ms/step - loss: 0.0011
# Epoch 82/100
# 46/46 [==============================] - 7s 155ms/step - loss: 9.9953e-04
# Epoch 83/100
# 46/46 [==============================] - 7s 150ms/step - loss: 9.8116e-04
# Epoch 84/100
# 46/46 [==============================] - 7s 149ms/step - loss: 0.0012
# Epoch 85/100
# 46/46 [==============================] - 7s 156ms/step - loss: 0.0010
# Epoch 86/100
# 46/46 [==============================] - 7s 144ms/step - loss: 9.7727e-04
# Epoch 87/100
# 46/46 [==============================] - 7s 157ms/step - loss: 0.0010
# Epoch 88/100
# 46/46 [==============================] - 7s 141ms/step - loss: 9.9660e-04
# Epoch 89/100
# 46/46 [==============================] - 7s 154ms/step - loss: 9.7784e-04
# Epoch 90/100
# 46/46 [==============================] - 6s 141ms/step - loss: 0.0011
# Epoch 91/100
# 46/46 [==============================] - 7s 142ms/step - loss: 8.4750e-04
# Epoch 92/100
# 46/46 [==============================] - 7s 148ms/step - loss: 9.0687e-04
# Epoch 93/100
# 46/46 [==============================] - 6s 136ms/step - loss: 8.3148e-04
# Epoch 94/100
# 46/46 [==============================] - 7s 145ms/step - loss: 0.0010
# Epoch 95/100
# 46/46 [==============================] - 6s 132ms/step - loss: 9.2897e-04
# Epoch 96/100
# 46/46 [==============================] - 7s 147ms/step - loss: 8.6060e-04
# Epoch 97/100
# 46/46 [==============================] - 7s 153ms/step - loss: 8.9986e-04
# Epoch 98/100
# 46/46 [==============================] - 6s 140ms/step - loss: 9.4904e-04
# Epoch 99/100
# 46/46 [==============================] - 7s 147ms/step - loss: 0.0011
# Epoch 100/100
# 46/46 [==============================] - 6s 139ms/step - loss: 9.8211e-04

# %%
dataset_test = pd.read_csv('Google_Stock_Price_Test.csv')

# %%
dataset_test.head()
# Out:
#          Date         Open         High          Low        Close   Volume
# 0  02/01/2018  1048.339966  1066.939941  1045.229980  1065.000000  1237600
# 1  03/01/2018  1064.310059  1086.290039  1063.209961  1082.479980  1430200
# 2  04/01/2018  1088.000000  1093.569946  1084.001953  1086.400024  1004600
# 3  05/01/2018  1094.000000  1104.250000  1092.000000  1102.229980  1279100
# 4  08/01/2018  1102.229980  1111.270020  1101.619995  1106.939941  1047600

# %%
real_stock_price = dataset_test.iloc[:, 1: 2].values
real_stock_price.shape
# Out:
# (125, 1)

# %%
#vertical concat use 0, horizontal uses 1
dataset_total = pd.concat((df['Open'], dataset_test['Open']), 
                          axis = 0)
inputs = dataset_total[len(dataset_total) - len(dataset_test) - 60:].values

# %%
inputs = inputs.reshape(-1, 1)

inputs = sc.transform(inputs)

# %%
len(inputs)
# Out:
# 185

# %%
X_test = []
for i in range(60, len(inputs)):
    X_test.append(inputs[i-60:i, 0])
X_test = np.array(X_test)

X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
X_test.shape
# Out:
# (125, 60, 1)

# %%
predicted_stock_price = regressor.predict(X_test)
# Out:
# 4/4 [==============================] - 4s 47ms/step

# %%
predicted_stock_price = sc.inverse_transform(predicted_stock_price)

# %%
plt.plot(real_stock_price, color = 'red', label = 'Real price')
plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted price')

plt.title('Google price prediction')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
